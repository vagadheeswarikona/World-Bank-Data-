# %%
import numpy as np
import pandas as pd

# %%
df_Fertility_rate=pd.read_csv("/content/drive/MyDrive/fertility_rate.csv")
df_Fertility_rate.head()
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  Fertility rate, total (births per woman)
# 1  Afghanistan          AFG  Fertility rate, total (births per woman)
# 2       Angola          AGO  Fertility rate, total (births per woman)
# 3      Albania          ALB  Fertility rate, total (births per woman)
# 4      Andorra          AND  Fertility rate, total (births per woman)
#
#    Indicator Code   1960   1961   1962   1963   1964   1965  ...   2007  \
# 0  SP.DYN.TFRT.IN  4.820  4.655  4.471  4.271  4.059  3.842  ...  1.763
# 1  SP.DYN.TFRT.IN  7.450  7.450  7.450  7.450  7.450  7.450  ...  6.460
# 2  SP.DYN.TFRT.IN  7.478  7.524  7.563  7.592  7.611  7.619  ...  6.368
# 3  SP.DYN.TFRT.IN  6.489  6.401  6.282  6.133  5.960  5.773  ...  1.668
# 4  SP.DYN.TFRT.IN    NaN    NaN    NaN    NaN    NaN    NaN  ...  1.180
#
#     2008   2009   2010   2011   2012   2013   2014   2015   2016
# ...

# %%
df_Life_Excetancy=pd.read_csv("/content/drive/MyDrive/life_expectancy.csv")
df_Life_Excetancy.head()
# Out:
#   Country Name Country Code                           Indicator Name  \
# 0        Aruba          ABW  Life expectancy at birth, total (years)
# 1  Afghanistan          AFG  Life expectancy at birth, total (years)
# 2       Angola          AGO  Life expectancy at birth, total (years)
# 3      Albania          ALB  Life expectancy at birth, total (years)
# 4      Andorra          AND  Life expectancy at birth, total (years)
#
#    Indicator Code    1960    1961    1962    1963    1964    1965  ...  \
# 0  SP.DYN.LE00.IN  65.662  66.074  66.444  66.787  67.113  67.435  ...
# 1  SP.DYN.LE00.IN  32.292  32.742  33.185  33.624  34.060  34.495  ...
# 2  SP.DYN.LE00.IN  33.251  33.573  33.914  34.272  34.645  35.031  ...
# 3  SP.DYN.LE00.IN  62.279  63.298  64.187  64.911  65.461  65.848  ...
# 4  SP.DYN.LE00.IN     NaN     NaN     NaN     NaN     NaN     NaN  ...
#
#      2007    2008    2009    2010    2011    2012    2013    2014    2015  \
# ...

# %%
df_Country_Population=pd.read_csv("/content/drive/MyDrive/country_population.csv")
df_Country_Population.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996351.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5643182.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965  ...        2007  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    101220.0
# 1  9166764.0  9345868.0  9533954.0  9731361.0  9938414.0  ...  26616792.0
# 2  5753024.0  5866061.0  5980417.0  6093321.0  6203299.0  ...  20997687.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2970017.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0  ...     82683.0
#
#          2008        2009        2010        2011        2012        2013  \
# ...

# %%
df_Metadata_Country=pd.read_csv("/content/drive/MyDrive/Metadata_Country.csv")
df_Metadata_Country.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFG                 South Asia           Low income
# 2          AGO         Sub-Saharan Africa  Lower middle income
# 3          ALB      Europe & Central Asia  Upper middle income
# 4          AND      Europe & Central Asia          High income
#
#                                         SpecialNotes    TableName  Unnamed: 5
# 0  SNA data for 2000-2011 are updated from offici...        Aruba         NaN
# 1  Fiscal year end: March 20; reporting period fo...  Afghanistan         NaN
# 2                                                NaN       Angola         NaN
# 3                                                NaN      Albania         NaN
# 4  WB-3 code changed from ADO to AND to align wit...      Andorra         NaN

# %%
print("Fertility_Rate:",df_Fertility_rate.shape)
print("Life_Excetancy:",df_Life_Excetancy.shape)
print("Country_Population:",df_Country_Population.shape)
print("Metadata_Country:",df_Metadata_Country.shape)
# Out:
# Fertility_Rate: (264, 61)
# Life_Excetancy: (264, 61)
# Country_Population: (264, 61)
# Metadata_Country: (263, 6)

# %% [markdown]
# #Fertility_Rate Table
#
# ---

# %%
df_Fertility_rate.info
# Out:
# <bound method DataFrame.info of      Country Name Country Code                            Indicator Name  \
# 0           Aruba          ABW  Fertility rate, total (births per woman)
# 1     Afghanistan          AFG  Fertility rate, total (births per woman)
# 2          Angola          AGO  Fertility rate, total (births per woman)
# 3         Albania          ALB  Fertility rate, total (births per woman)
# 4         Andorra          AND  Fertility rate, total (births per woman)
# ..            ...          ...                                       ...
# 259        Kosovo          XKX  Fertility rate, total (births per woman)
# 260   Yemen, Rep.          YEM  Fertility rate, total (births per woman)
# 261  South Africa          ZAF  Fertility rate, total (births per woman)
# 262        Zambia          ZMB  Fertility rate, total (births per woman)
# 263      Zimbabwe          ZWE  Fertility rate, total (births per woman)
#
# ...

# %%
df_Fertility_rate.describe()
# Out:
#              1960        1961        1962        1963        1964        1965  \
# count  236.000000  237.000000  236.000000  235.000000  236.000000  236.000000
# mean     5.508217    5.493573    5.495798    5.495507    5.458346    5.415664
# std      1.676953    1.693979    1.705126    1.706969    1.729399    1.759863
# min      1.940000    1.940000    1.790000    1.820000    1.790000    1.740000
# 25%      4.322250    4.313000    4.245000    4.208500    4.049750    3.876500
# 50%      6.104500    6.073000    6.090896    6.131760    6.047000    5.983636
# 75%      6.767554    6.762000    6.775408    6.787614    6.783250    6.773954
# max      8.187000    8.194000    8.197000    8.198000    8.198000    8.198000
#
#              1966        1967        1968        1969  ...        2007  \
# count  236.000000  236.000000  236.000000  236.000000  ...  249.000000
# mean     5.365999    5.327700    5.274330    5.219431  ...    2.982628
# ...

# %%
df_Fertility_rate.isna().sum()
# Out:
# Country Name       0
# Country Code       0
# Indicator Name     0
# Indicator Code     0
# 1960              28
#                   ..
# 2012              16
# 2013              18
# 2014              18
# 2015              17
# 2016              18
# Length: 61, dtype: int64

# %%
df_Fertility_rate.dropna(inplace=True)
df_Fertility_rate.shape
# Out:
# (235, 61)

# %%
df_Fertility_rate.duplicated().sum()
# Out:
# 0

# %%
df_Fertility_rate.shape
# Out:
# (235, 61)

# %%
df_Fertility_rate.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2012              float64
# 2013              float64
# 2014              float64
# 2015              float64
# 2016              float64
# Length: 61, dtype: object

# %%
df_Fertility_rate.drop(["Indicator Name","Indicator Code"],inplace=True,axis=1)
df_Fertility_rate.head()
# Out:
#   Country Name Country Code      1960     1961     1962      1963      1964  \
# 0        Aruba          ABW  4.820000  4.65500  4.47100  4.271000  4.059000
# 1  Afghanistan          AFG  7.450000  7.45000  7.45000  7.450000  7.450000
# 2       Angola          AGO  7.478000  7.52400  7.56300  7.592000  7.611000
# 3      Albania          ALB  6.489000  6.40100  6.28200  6.133000  5.960000
# 5   Arab World          ARB  6.948747  6.97137  6.99235  7.009265  7.020105
#
#        1965      1966      1967  ...      2007      2008      2009      2010  \
# 0  3.842000  3.625000  3.417000  ...  1.763000  1.764000  1.769000  1.776000
# 1  7.450000  7.450000  7.450000  ...  6.460000  6.254000  6.038000  5.816000
# 2  7.619000  7.618000  7.613000  ...  6.368000  6.307000  6.238000  6.162000
# 3  5.773000  5.581000  5.394000  ...  1.668000  1.650000  1.646000  1.653000
# 5  7.023159  7.015824  6.998628  ...  3.476805  3.470126  3.469736  3.471666
#
# ...

# %% [markdown]
# #Life_Expectancy
#
# ---

# %%
df_Life_Excetancy.shape
# Out:
# (264, 61)

# %%
df_Life_Excetancy.info
# Out:
# <bound method DataFrame.info of      Country Name Country Code                           Indicator Name  \
# 0           Aruba          ABW  Life expectancy at birth, total (years)
# 1     Afghanistan          AFG  Life expectancy at birth, total (years)
# 2          Angola          AGO  Life expectancy at birth, total (years)
# 3         Albania          ALB  Life expectancy at birth, total (years)
# 4         Andorra          AND  Life expectancy at birth, total (years)
# ..            ...          ...                                      ...
# 259        Kosovo          XKX  Life expectancy at birth, total (years)
# 260   Yemen, Rep.          YEM  Life expectancy at birth, total (years)
# 261  South Africa          ZAF  Life expectancy at birth, total (years)
# 262        Zambia          ZMB  Life expectancy at birth, total (years)
# 263      Zimbabwe          ZWE  Life expectancy at birth, total (years)
#
# ...

# %%
df_Life_Excetancy.describe()
# Out:
#              1960        1961        1962        1963        1964        1965  \
# count  235.000000  236.000000  236.000000  235.000000  235.000000  236.000000
# mean    53.367005   53.919724   54.313463   54.691397   55.183426   55.670319
# std     11.808866   11.814552   11.672652   11.563223   11.524424   11.403835
# min     28.199000   28.345000   28.535000   28.782000   29.097000   29.489000
# 25%     43.546550   44.141000   44.822000   45.232000   45.923000   46.660750
# 50%     52.265000   53.273000   54.284500   54.932000   55.407000   55.859860
# 75%     63.834056   64.460750   65.094750   65.180150   65.424500   66.014012
# max     73.549756   73.652683   73.721951   73.555366   73.733171   73.868780
#
#              1966        1967        1968        1969  ...        2007  \
# count  236.000000  236.000000  236.000000  236.000000  ...  247.000000
# mean    56.136662   56.562796   56.959702   57.344205  ...   69.163359
# ...

# %%
df_Life_Excetancy.isna().sum()
# Out:
# Country Name       0
# Country Code       0
# Indicator Name     0
# Indicator Code     0
# 1960              29
#                   ..
# 2012              17
# 2013              19
# 2014              19
# 2015              20
# 2016              19
# Length: 61, dtype: int64

# %%
df_Life_Excetancy.dropna(inplace=True)
df_Life_Excetancy.shape
# Out:
# (235, 61)

# %%
df_Life_Excetancy.duplicated().sum()
# Out:
# 0

# %%
df_Life_Excetancy.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2012              float64
# 2013              float64
# 2014              float64
# 2015              float64
# 2016              float64
# Length: 61, dtype: object

# %%
df_Life_Excetancy.drop(["Indicator Name","Indicator Code"],inplace=True,axis=1)
df_Life_Excetancy.head()
# Out:
#   Country Name Country Code       1960       1961       1962       1963  \
# 0        Aruba          ABW  65.662000  66.074000  66.444000  66.787000
# 1  Afghanistan          AFG  32.292000  32.742000  33.185000  33.624000
# 2       Angola          AGO  33.251000  33.573000  33.914000  34.272000
# 3      Albania          ALB  62.279000  63.298000  64.187000  64.911000
# 5   Arab World          ARB  46.825065  47.407699  47.988878  48.572229
#
#         1964       1965    1966       1967  ...       2007      2008  \
# 0  67.113000  67.435000  67.762  68.095000  ...  74.576000  74.72500
# 1  34.060000  34.495000  34.928  35.361000  ...  59.694000  60.24300
# 2  34.645000  35.031000  35.426  35.828000  ...  55.096000  56.18900
# 3  65.461000  65.848000  66.108  66.302000  ...  75.656000  75.94300
# 5  49.159167  49.744338  50.319  50.876461  ...  69.424552  69.64697
#
#         2009       2010       2011       2012       2013       2014  \
# ...

# %% [markdown]
# #**Country_Population**
#
# ---

# %%
df_Country_Population.shape
# Out:
# (264, 61)

# %%
df_Country_Population.info
# Out:
# <bound method DataFrame.info of      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 0           Aruba          ABW  Population, total    SP.POP.TOTL     54211.0
# 1     Afghanistan          AFG  Population, total    SP.POP.TOTL   8996351.0
# 2          Angola          AGO  Population, total    SP.POP.TOTL   5643182.0
# 3         Albania          ALB  Population, total    SP.POP.TOTL   1608800.0
# 4         Andorra          AND  Population, total    SP.POP.TOTL     13411.0
# ..            ...          ...                ...            ...         ...
# 259        Kosovo          XKX  Population, total    SP.POP.TOTL    947000.0
# 260   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5172135.0
# 261  South Africa          ZAF  Population, total    SP.POP.TOTL  17456855.0
# 262        Zambia          ZMB  Population, total    SP.POP.TOTL   3044846.0
# 263      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3747369.0
#
# ...

# %%
df_Country_Population.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.600000e+02  2.600000e+02  2.600000e+02  2.600000e+02  2.600000e+02
# mean   1.181558e+08  1.197450e+08  1.218673e+08  1.245078e+08  1.271694e+08
# std    3.734003e+08  3.778906e+08  3.844786e+08  3.930580e+08  4.016827e+08
# min    4.279000e+03  4.453000e+03  4.566000e+03  4.656000e+03  4.748000e+03
# 25%    5.184015e+05  5.301480e+05  5.426568e+05  5.559520e+05  5.684168e+05
# 50%    3.669524e+06  3.734206e+06  3.839584e+06  3.955168e+06  4.074411e+06
# 75%    2.532754e+07  2.611541e+07  2.690508e+07  2.770050e+07  2.847884e+07
# max    3.032160e+09  3.073369e+09  3.126510e+09  3.191786e+09  3.257460e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.600000e+02  2.600000e+02  2.600000e+02  2.600000e+02  2.600000e+02
# mean   1.298972e+08  1.327702e+08  1.356381e+08  1.385571e+08  1.416185e+08
# ...

# %%
df_Country_Population.isna().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              4
#                  ..
# 2012              2
# 2013              2
# 2014              2
# 2015              2
# 2016              2
# Length: 61, dtype: int64

# %%
df_Country_Population1=df_Country_Population.dropna()
df_Country_Population1.shape
# Out:
# (258, 61)

# %%
df_Country_Population1.duplicated().sum()
# Out:
# 0

# %%
df_Country_Population1.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2012              float64
# 2013              float64
# 2014              float64
# 2015              float64
# 2016              float64
# Length: 61, dtype: object

# %%
df_Country_Population.drop(["Indicator Name","Indicator Code"],inplace=True,axis=1)
df_Country_Population.head()
# Out:
#   Country Name Country Code       1960       1961       1962       1963  \
# 0        Aruba          ABW    54211.0    55438.0    56225.0    56695.0
# 1  Afghanistan          AFG  8996351.0  9166764.0  9345868.0  9533954.0
# 2       Angola          AGO  5643182.0  5753024.0  5866061.0  5980417.0
# 3      Albania          ALB  1608800.0  1659800.0  1711319.0  1762621.0
# 4      Andorra          AND    13411.0    14375.0    15370.0    16412.0
#
#         1964       1965        1966        1967  ...        2007        2008  \
# 0    57032.0    57360.0     57715.0     58055.0  ...    101220.0    101353.0
# 1  9731361.0  9938414.0  10152331.0  10372630.0  ...  26616792.0  27294031.0
# 2  6093321.0  6203299.0   6309770.0   6414995.0  ...  20997687.0  21759420.0
# 3  1814135.0  1864791.0   1914573.0   1965598.0  ...   2970017.0   2947314.0
# 4    17469.0    18549.0     19647.0     20758.0  ...     82683.0     83861.0
#
# ...

# %% [markdown]
# #Melt the DataSets(Fertility_Rate, Population, Life_Expectancy)

# %%
years=[str(i) for i in range(1960,2017)]

# %%
df_Fertility_rate.head()
# Out:
#   Country Name Country Code      1960     1961     1962      1963      1964  \
# 0        Aruba          ABW  4.820000  4.65500  4.47100  4.271000  4.059000
# 1  Afghanistan          AFG  7.450000  7.45000  7.45000  7.450000  7.450000
# 2       Angola          AGO  7.478000  7.52400  7.56300  7.592000  7.611000
# 3      Albania          ALB  6.489000  6.40100  6.28200  6.133000  5.960000
# 5   Arab World          ARB  6.948747  6.97137  6.99235  7.009265  7.020105
#
#        1965      1966      1967  ...      2007      2008      2009      2010  \
# 0  3.842000  3.625000  3.417000  ...  1.763000  1.764000  1.769000  1.776000
# 1  7.450000  7.450000  7.450000  ...  6.460000  6.254000  6.038000  5.816000
# 2  7.619000  7.618000  7.613000  ...  6.368000  6.307000  6.238000  6.162000
# 3  5.773000  5.581000  5.394000  ...  1.668000  1.650000  1.646000  1.653000
# 5  7.023159  7.015824  6.998628  ...  3.476805  3.470126  3.469736  3.471666
#
# ...

# %%
df_Fertility_rate_Melt=pd.melt(df_Fertility_rate,
                               id_vars=['Country Name',"Country Code"],
                               value_vars=years,
                               var_name="Year",
                               value_name="Fertility_Rate")
df_Fertility_rate_Melt.head()
# Out:
#   Country Name Country Code  Year  Fertility_Rate
# 0        Aruba          ABW  1960        4.820000
# 1  Afghanistan          AFG  1960        7.450000
# 2       Angola          AGO  1960        7.478000
# 3      Albania          ALB  1960        6.489000
# 4   Arab World          ARB  1960        6.948747

# %%
df_Fertility_rate_Melt.shape
# Out:
# (13395, 4)

# %%
df_Life_Excetancy.head()
# Out:
#   Country Name Country Code       1960       1961       1962       1963  \
# 0        Aruba          ABW  65.662000  66.074000  66.444000  66.787000
# 1  Afghanistan          AFG  32.292000  32.742000  33.185000  33.624000
# 2       Angola          AGO  33.251000  33.573000  33.914000  34.272000
# 3      Albania          ALB  62.279000  63.298000  64.187000  64.911000
# 5   Arab World          ARB  46.825065  47.407699  47.988878  48.572229
#
#         1964       1965    1966       1967  ...       2007      2008  \
# 0  67.113000  67.435000  67.762  68.095000  ...  74.576000  74.72500
# 1  34.060000  34.495000  34.928  35.361000  ...  59.694000  60.24300
# 2  34.645000  35.031000  35.426  35.828000  ...  55.096000  56.18900
# 3  65.461000  65.848000  66.108  66.302000  ...  75.656000  75.94300
# 5  49.159167  49.744338  50.319  50.876461  ...  69.424552  69.64697
#
#         2009       2010       2011       2012       2013       2014  \
# ...

# %%
df_Life_Excetancy_Melt=pd.melt(df_Life_Excetancy,
                               id_vars=['Country Name',"Country Code"],
                               value_vars=years,
                               var_name="Year",
                               value_name="Life_Expectancy")
df_Life_Excetancy_Melt.head()
# Out:
#   Country Name Country Code  Year  Life_Expectancy
# 0        Aruba          ABW  1960        65.662000
# 1  Afghanistan          AFG  1960        32.292000
# 2       Angola          AGO  1960        33.251000
# 3      Albania          ALB  1960        62.279000
# 4   Arab World          ARB  1960        46.825065

# %%
df_Life_Excetancy_Melt.shape
# Out:
# (13395, 4)

# %%
df_Country_Population1.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996351.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5643182.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965  ...        2007  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    101220.0
# 1  9166764.0  9345868.0  9533954.0  9731361.0  9938414.0  ...  26616792.0
# 2  5753024.0  5866061.0  5980417.0  6093321.0  6203299.0  ...  20997687.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2970017.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0  ...     82683.0
#
#          2008        2009        2010        2011        2012        2013  \
# ...

# %%
df_Country_Population_Melt=pd.melt(df_Country_Population1,
                                   id_vars=['Country Name',"Country Code"],
                                   value_vars=years,
                                   var_name="Year",
                                   value_name="Population")

# %%
df_Country_Population_Melt.head()
# Out:
#   Country Name Country Code  Year  Population
# 0        Aruba          ABW  1960     54211.0
# 1  Afghanistan          AFG  1960   8996351.0
# 2       Angola          AGO  1960   5643182.0
# 3      Albania          ALB  1960   1608800.0
# 4      Andorra          AND  1960     13411.0

# %%
df_Country_Population_Melt.shape
# Out:
# (14706, 4)

# %%
df_Fertility_rate_Melt.duplicated().sum()
# Out:
# 0

# %%
df_Life_Excetancy_Melt.duplicated().sum()
# Out:
# 0

# %%
df_Country_Population_Melt.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #Merge the all tables(Life_expectancy, Fertility_rate, Country_population, Metadata_Country)

# %%
df_Metadata_Country.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFG                 South Asia           Low income
# 2          AGO         Sub-Saharan Africa  Lower middle income
# 3          ALB      Europe & Central Asia  Upper middle income
# 4          AND      Europe & Central Asia          High income
#
#                                         SpecialNotes    TableName  Unnamed: 5
# 0  SNA data for 2000-2011 are updated from offici...        Aruba         NaN
# 1  Fiscal year end: March 20; reporting period fo...  Afghanistan         NaN
# 2                                                NaN       Angola         NaN
# 3                                                NaN      Albania         NaN
# 4  WB-3 code changed from ADO to AND to align wit...      Andorra         NaN

# %%
df_Metadata_Country = df_Metadata_Country[['Country Code', 'Region']]
df_Metadata_Country.head()
# Out:
#   Country Code                     Region
# 0          ABW  Latin America & Caribbean
# 1          AFG                 South Asia
# 2          AGO         Sub-Saharan Africa
# 3          ALB      Europe & Central Asia
# 4          AND      Europe & Central Asia

# %%
df_Metadata_Country.isna().sum()
# Out:
# Country Code     0
# Region          46
# dtype: int64

# %%
country_region_mapping = df_Metadata_Country.dropna().set_index('Country Code')['Region'].to_dict()
df_Metadata_Country['Region'] = df_Metadata_Country.apply(
    lambda row: country_region_mapping.get(row['Country Code'], row['Region']) if pd.isna(row['Region']) else row['Region'], axis=1
)

# %%
df_Metadata_Country.duplicated().sum()
# Out:
# 0

# %%
df_Metadata_Country.dropna(inplace=True)
df_Metadata_Country.shape
# Out:
# (217, 2)

# %%
df_merge1 = pd.merge(df_Metadata_Country,df_Country_Population_Melt,how='left', on=['Country Code'])
df_merge1.head()
# Out:
#   Country Code                     Region Country Name  Year  Population
# 0          ABW  Latin America & Caribbean        Aruba  1960     54211.0
# 1          ABW  Latin America & Caribbean        Aruba  1961     55438.0
# 2          ABW  Latin America & Caribbean        Aruba  1962     56225.0
# 3          ABW  Latin America & Caribbean        Aruba  1963     56695.0
# 4          ABW  Latin America & Caribbean        Aruba  1964     57032.0

# %%
df_merge1.shape
# Out:
# (12089, 5)

# %%
df_merge2= pd.merge(df_merge1,df_Life_Excetancy_Melt,how='left', on=['Country Code','Year','Country Name'])
df_merge2.head()
# Out:
#   Country Code                     Region Country Name  Year  Population  \
# 0          ABW  Latin America & Caribbean        Aruba  1960     54211.0
# 1          ABW  Latin America & Caribbean        Aruba  1961     55438.0
# 2          ABW  Latin America & Caribbean        Aruba  1962     56225.0
# 3          ABW  Latin America & Caribbean        Aruba  1963     56695.0
# 4          ABW  Latin America & Caribbean        Aruba  1964     57032.0
#
#    Life_Expectancy
# 0           65.662
# 1           66.074
# 2           66.444
# 3           66.787
# 4           67.113

# %%
df_merge3= pd.merge(df_merge2,df_Fertility_rate_Melt,how='left', on=['Country Code','Year','Country Name'])
df_merge3.head()
# Out:
#   Country Code                     Region Country Name  Year  Population  \
# 0          ABW  Latin America & Caribbean        Aruba  1960     54211.0
# 1          ABW  Latin America & Caribbean        Aruba  1961     55438.0
# 2          ABW  Latin America & Caribbean        Aruba  1962     56225.0
# 3          ABW  Latin America & Caribbean        Aruba  1963     56695.0
# 4          ABW  Latin America & Caribbean        Aruba  1964     57032.0
#
#    Life_Expectancy  Fertility_Rate
# 0           65.662           4.820
# 1           66.074           4.655
# 2           66.444           4.471
# 3           66.787           4.271
# 4           67.113           4.059

# %%
df_merge3.shape
# Out:
# (12089, 7)

# %%
df_merge3.isna().sum()
# Out:
# Country Code          0
# Region                0
# Country Name          5
# Year                  5
# Population            5
# Life_Expectancy    1430
# Fertility_Rate     1430
# dtype: int64

# %%
df_merge3.duplicated().sum()
# Out:
# 0

# %%
df_merge3.describe()
# Out:
#          Population  Life_Expectancy  Fertility_Rate
# count  1.208400e+04     10659.000000    10659.000000
# mean   2.411209e+07        63.555301        4.100955
# std    1.005657e+08        11.428331        2.031601
# min    4.279000e+03        18.907000        0.827000
# 25%    4.347062e+05        55.486500        2.187000
# 50%    4.137006e+06        66.541000        3.783000
# 75%    1.322379e+07        72.179000        6.025000
# max    1.378665e+09        84.278049        8.866000

# %%
df_merge3.dtypes
# Out:
# Country Code        object
# Region              object
# Country Name        object
# Year                object
# Population         float64
# Life_Expectancy    float64
# Fertility_Rate     float64
# dtype: object

# %%
for index, row in df_merge3.iterrows():
    if pd.isna(row['Population']):
        previous_value = df_merge3.loc[index - 1, 'Population'] if index > 0 else np.nan
        next_value = df_merge3.loc[index + 1, 'Population'] if index < len(df_merge3) - 1 else np.nan
        if not pd.isna(previous_value) and not pd.isna(next_value):
            df_merge3.at[index, 'Population'] = (previous_value + next_value) / 2

# %%
df_merge3.isna().sum()
# Out:
# Country Code          0
# Region                0
# Country Name          5
# Year                  5
# Population            0
# Life_Expectancy    1430
# Fertility_Rate     1430
# dtype: int64

# %%
import matplotlib.pyplot as plt
df_merge3['Year'] = pd.to_numeric(df_merge3['Year'])
population_trends = df_merge3.groupby('Year')['Population'].sum()
# Splitting the data into four parts
part1 = population_trends.loc['1960':'1974']
part2 = population_trends.loc['1975':'1989']
part3 = population_trends.loc['1990':'2004']
part4 = population_trends.loc['2005':'2016']

# Plotting the line graphs for each part
plt.figure(figsize=(20, 12))

plt.subplot(2, 2, 1)
part1.plot(kind='line')
plt.title('Population Trends (1960-1974)')
plt.xlabel('Year')
plt.ylabel('Population')
plt.grid(True)

plt.subplot(2, 2, 2)
part2.plot(kind='line')
plt.title('Population Trends (1975-1989)')
plt.xlabel('Year')
plt.ylabel('Population')
plt.grid(True)

plt.subplot(2, 2, 3)
part3.plot(kind='line')
plt.title('Population Trends (1990-2004)')
plt.xlabel('Year')
plt.ylabel('Population')
plt.grid(True)

plt.subplot(2, 2, 4)
part4.plot(kind='line')
plt.title('Population Trends (2005-2016)')
plt.xlabel('Year')
plt.ylabel('Population')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
for index, row in df_merge3.iterrows():
    if pd.isna(row['Life_Expectancy']):
        # Check for previous and next values
        previous_value = df_merge3.loc[index - 1, 'Life_Expectancy'] if index > 0 else np.nan
        next_value = df_merge3.loc[index + 1, 'Life_Expectancy'] if index < len(df_merge3) - 1 else np.nan

        # Fill if both neighbors are not NaN
        if not pd.isna(previous_value) and not pd.isna(next_value):
            df_merge3.at[index, 'Life_Expectancy'] = (previous_value + next_value) / 2
        # If only one neighbor is available
        elif not pd.isna(previous_value):
            df_merge3.at[index, 'Life_Expectancy'] = previous_value
        elif not pd.isna(next_value):
            df_merge3.at[index, 'Life_Expectancy'] = next_value

# %%
df_merge3.isna().sum()
# Out:
# Country Code          0
# Region                0
# Country Name          5
# Year                  5
# Population            0
# Life_Expectancy       0
# Fertility_Rate     1430
# dtype: int64

# %%
import seaborn as sns

# Plotting a distribution plot for life expectancy
plt.figure(figsize=(10, 6))
sns.histplot(df_merge3['Life_Expectancy'].dropna(), kde=True)
plt.title('Distribution of Life Expectancy')
plt.xlabel('Life Expectancy')
plt.ylabel('Frequency')
plt.show()

# %%
for index, row in df_merge3.iterrows():
    if pd.isna(row['Fertility_Rate']):
        # Check for previous and next values
        previous_value = df_merge3.loc[index - 1, 'Fertility_Rate'] if index > 0 else np.nan
        next_value = df_merge3.loc[index + 1, 'Fertility_Rate'] if index < len(df_merge3) - 1 else np.nan

        # Fill if both neighbors are not NaN
        if not pd.isna(previous_value) and not pd.isna(next_value):
            df_merge3.at[index, 'Fertility_Rate'] = (previous_value + next_value) / 2
        # If only one neighbor is available
        elif not pd.isna(previous_value):
            df_merge3.at[index, 'Fertility_Rate'] = previous_value
        elif not pd.isna(next_value):
            df_merge3.at[index, 'Fertility_Rate'] = next_value

# %%
df_merge3.isna().sum()
# Out:
# Country Code       0
# Region             0
# Country Name       5
# Year               5
# Population         0
# Life_Expectancy    0
# Fertility_Rate     0
# dtype: int64

# %%
df_merge3.dropna(inplace=True)
df_merge3.shape
# Out:
# (12084, 7)

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_merge3['Fertility_Rate'].dropna(), kde=True)
plt.title('Distribution of Fertility Rate')
plt.xlabel('Fertility Rate')
plt.ylabel('Frequency')
plt.show()

# %%
df_merge3.isna().sum()
# Out:
# Country Code       0
# Region             0
# Country Name       0
# Year               0
# Population         0
# Life_Expectancy    0
# Fertility_Rate     0
# dtype: int64

# %%
# Correlation matrix
correlation_matrix = df_merge3[['Population', 'Life_Expectancy', 'Fertility_Rate']].corr()

# Plotting the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %%
df_merge3.tail()
# Out:
#       Country Code              Region Country Name  Year  Population  \
# 12084          ZWE  Sub-Saharan Africa     Zimbabwe  2012  14710826.0
# 12085          ZWE  Sub-Saharan Africa     Zimbabwe  2013  15054506.0
# 12086          ZWE  Sub-Saharan Africa     Zimbabwe  2014  15411675.0
# 12087          ZWE  Sub-Saharan Africa     Zimbabwe  2015  15777451.0
# 12088          ZWE  Sub-Saharan Africa     Zimbabwe  2016  16150362.0
#
#        Life_Expectancy  Fertility_Rate
# 12084           56.516           3.996
# 12085           58.053           3.957
# 12086           59.360           3.903
# 12087           60.398           3.836
# 12088           61.163           3.760

# %%
# Grouping by Region and summing Population
regional_population = df_merge3.groupby('Region')['Population'].sum()
# Plotting the bar chart
plt.figure(figsize=(10, 6))
regional_population.plot(kind='bar')
plt.title('Population by Region')
plt.xlabel('Region')
plt.ylabel('Population')
plt.xticks(rotation=45)
plt.show()

# %%
# Plotting box plot for life expectancy by region
plt.figure(figsize=(12, 6))
sns.boxplot(x='Region', y='Life_Expectancy', data=df_merge3)
plt.title('Life Expectancy by Region')
plt.xlabel('Region')
plt.ylabel('Life Expectancy')
plt.xticks(rotation=45)
plt.show()

# %%
import plotly.express as px
fig = px.scatter(df_merge3,
                 x="Fertility_Rate",
                 y="Life_Expectancy",
                 animation_frame="Year",
                 animation_group="Country Name",
                 size="Population",
                 color="Region",
                 hover_name="Country Name",
                 log_x=False,
                 size_max=50,
                 #range_x=[df_merge3["Population"].min(), df_merge3["Population"].max()],
                 #range_y=[df_merge3["Life_Expectancy"].min(), df_merge3["Life_Expectancy"].max()],
                 range_x=[0,10],
                 range_y=[10, 90],
                 width=1000,
                 height=650)

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
